# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/pythonprograms/blob/main/infinite_comp_solutions_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=["a",1,2,"b",99]

list(filter(lambda x:type(x)==int,list1))
# Out:
# [1, 2, 99]

# %%
list2=["a","acvhgvgh","ghj","b","hjhjj"]

list(map(str.upper,list2))
# Out:
# ['A', 'ACVHGVGH', 'GHJ', 'B', 'HJHJJ']

# %%
s1="aaczabaffa"
res=""
for i in s1:
  if i not in res:
    res+=i
print(res)
# Out:
# aczbf

# %%
s1="aaczabaffa"
d={}
for i in s1:
  if i not in d:
    d[i]=1
  else:
    d[i]+=1

res=dict(sorted(d.items(),key=lambda x:x[1]))
res
# Out:
# {'c': 1, 'z': 1, 'b': 1, 'f': 2, 'a': 5}

# %%
res=lambda x,y,z:x+y+z
res(5,6,11)
# Out:
# 22

# %%
a=1,

print(type(a))
# Out:
# <class 'tuple'>

# %%
{(1,2,3):"a",(1):"b"}
# Out:
# {(1, 2, 3): 'a', 1: 'b'}

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("/content/employee_data.xlsx")

# %%
df=df[["EmpID","LocationCode","Current Employee Rating"]]

# %%
df
# Out:
#       EmpID  LocationCode  Current Employee Rating
# 0      3427         34904                        4
# 1      3428          6593                        3
# 2      3429          2330                        4
# 3      3430         58782                        2
# 4      3431         33174                        3
# ...     ...           ...                      ...
# 2995   3422         44500                        3
# 2996   3423         35444                        3
# 2997   3424          6608                        2
# 2998   3425          3807                        2
# 2999   3426         57487                        2
#
# [3000 rows x 3 columns]

# %%
df["LocationCode"]=np.where(df["Current Employee Rating"]==4 ,df["LocationCode"]+df["LocationCode"]*0.30,df["LocationCode"])
df["LocationCode"]=np.where(df["Current Employee Rating"]==3 ,df["LocationCode"]+df["LocationCode"]*0.10,df["LocationCode"])
df["LocationCode"]=np.where(df["Current Employee Rating"]==2 ,df["LocationCode"]+df["LocationCode"]*0.05,df["LocationCode"])

# %%
df
# Out:
#       EmpID  LocationCode  Current Employee Rating
# 0      3427      45375.20                        4
# 1      3428       7252.30                        3
# 2      3429       3029.00                        4
# 3      3430      61721.10                        2
# 4      3431      36491.40                        3
# ...     ...           ...                      ...
# 2995   3422      48950.00                        3
# 2996   3423      38988.40                        3
# 2997   3424       6938.40                        2
# 2998   3425       3997.35                        2
# 2999   3426      60361.35                        2
#
# [3000 rows x 3 columns]
